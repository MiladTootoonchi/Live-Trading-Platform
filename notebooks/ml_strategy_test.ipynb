# %% [markdown]
# # Testing ML_strategy function
# This notebook is only going to test if the ml_strategy function returns expected values.

# %% [markdown]
# ### Importing

# %%
import sys
from pathlib import Path
import requests
import asyncio

sys.path.append(str(Path("..").resolve()))

from src.ml_model.ml_strategy import AI_strategy
from config import load_api_keys
# Out:
# 2025-11-11 15:43:53.847596: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-11 15:43:53.913115: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-11 15:43:55.445557: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ### Getting positions

# %%
# Loading keys
key, secret_key = load_api_keys() 

HEADERS = {
        "APCA-API-KEY-ID" : key,
        "APCA-API-SECRET-KEY": secret_key,
}

APCA_API_BASE_URL =  "https://paper-api.alpaca.markets"

url = f"{APCA_API_BASE_URL}/v2/positions"
response = await asyncio.to_thread(requests.get, url, headers = HEADERS)
positions = response.json()

# %% [markdown]
# ### Checking the signals and qty for each position

# %%
for position in positions:
    symbol_i = position.get("symbol")
    signal, qty = await AI_strategy(position)
    
    print(f"{symbol_i}: the AI says you should {signal} with qty = {qty}")
# Out:
# Epoch 1/20
# 2025-11-11 15:43:56.955646: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 61/61 - 2s - 26ms/step - accuracy: 0.5031 - loss: 0.7002 - val_accuracy: 0.5093 - val_loss: 0.6985
# Epoch 2/20
# 61/61 - 0s - 4ms/step - accuracy: 0.5289 - loss: 0.6904 - val_accuracy: 0.4630 - val_loss: 0.7019
# Epoch 3/20
# 61/61 - 0s - 3ms/step - accuracy: 0.5402 - loss: 0.6911 - val_accuracy: 0.4259 - val_loss: 0.7056
# Epoch 4/20
# 61/61 - 0s - 4ms/step - accuracy: 0.5412 - loss: 0.6881 - val_accuracy: 0.4074 - val_loss: 0.7091
# Epoch 5/20
# 61/61 - 0s - 4ms/step - accuracy: 0.5536 - loss: 0.6878 - val_accuracy: 0.3889 - val_loss: 0.7117
# Epoch 6/20
# 61/61 - 0s - 4ms/step - accuracy: 0.5485 - loss: 0.6869 - val_accuracy: 0.3796 - val_loss: 0.7200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# AAPL: the AI says you should SideSignal.HOLD with qty = 0

# %%
signal, qty
# Out:
# (<SideSignal.HOLD: 'hold'>, 0)

# %% [markdown]
# ### Suggestions
# * We will send a hold signal if the qty = 0     (DONE)
